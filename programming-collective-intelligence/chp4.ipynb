# %%
#search engine stuff
#this is defined at the very start of the chapter and then added to
#during the chapter

import urllib
import urllib.request
import sqlite3 as sql
import os
import re

class Crawler:
    #initialise with name of the db
    def __init__(self, db_name):
        self.con = sql.connect(db_name)
    
    def __del__(self):
        self.con.close()
    
    def db_commit(self):
        self.con.commit()
    
    def get_entry_id(self, table, field, value, create_new=True):
        #function for getting entry id and adding if not present
        cur = self.con.execute("select rowid from %s where %s='%s'" % (table,field,value))
        res = cur.fetchone()
        if res == None:
            cur = self.con.execute("insert into %s (%s) values ('%s')" % (table,field,value))
            return cur.lastrowid
        else:
            return res[0]
    
    def add_to_index(self, url, soup):
        #index an individual page
        if self.is_indexed(url):
            return
        print("Indexing %s" % url)
        
        #get individual words
        text = self.get_text_only(soup)
        words = self.separate_words(text)
        
        #get url id
        url_id = self.get_entry_id('url_list', 'url', url)
        
        #link each word to this url
        for i, w in enumerate(words):
            word = w
            if word in ignore_words:
                continue
            word_id = self.get_entry_id('word_list', 'word', word)
            self.con.execute('insert into word_location(url_id,word_id,location) values (%d,%d,%d)' % (url_id,word_id,i))
        
    def get_text_only(self, soup):
        #extract text from a HTML page (no tags)
        v = soup.string
        if v == None:
            c = soup.contents
            result_text = ''
            for t in c:
                sub_text = self.get_text_only(t)
                result_text += sub_text + '\n'
            return result_text
        else:
            return v.strip()
    
    def separate_words(self, text):
        #separate words by any non-whitespace character
        splitter = re.compile('\\W*')
        return [s.lower() for s in splitter.split(text) if s != '']
        return None
    
    def is_indexed(self, url):
        #return true if this url is already indexed
        u = self.con.execute("select rowid from url_list where url='%s'" % url).fetchone()
        if u != None:
            #check if it has actually been crawled
            v = self.con.execute("select * from word_location where url_id=%d" % u[0]).fetchone()
            if v != None:
                return True
        return False
    
    def add_link_ref(self, url_from, url_to, link_text):
        #add link between two pages
        pass
    
    def crawl(self, pages, depth=2):
        #starting with list of pages do BFS to depth given
        #indexing pages as we go
        for i in range(depth):
            new_pages = set()
            for page in pages:
                try:
                    c = urllib.request.urlopen(page)
                except:
                    print("Could not open %s" % page)
                    continue
                soup = bs4.BeautifulSoup(c.read())
                self.add_to_index(page, soup)
                
                links = soup('a')
                for link in links:
                    if ('href' in dict(link.attrs)):
                        url = urllib.parse.urljoin(page, link['href'])
                        if url.find("'") != -1:
                            continue
                        url = url.split('#')[0] #remove location portion
                        if url[0:4] == 'http' and not self.is_indexed(url):
                            new_pages.add(url)
                        link_text = self.get_text_only(link)
                        self.add_link_ref(page, url, link_text)
                        
                self.db_commit()
                
            pages = new_pages
        
    def create_index_tables(self):
        #create the databse tables
        self.con.execute('create table url_list(url)')
        self.con.execute('create table word_list(word)')
        self.con.execute('create table word_location(url_id,word_id,location)')
        self.con.execute('create table link(from_id integer,to_id integer)')
        self.con.execute('create table link_words(word_id,link_id)')
        self.con.execute('create index word_idx on word_list(word)')
        self.con.execute('create index url_idx on url_list(url)')
        self.con.execute('create index word_url_idx on word_location(word_id)')
        self.con.execute('create index url_to_idx on link(to_id)')
        self.con.execute('create index url_from_idx on link(from_id)')
        self.db_commit( )

# %%
#following links from one page to linked pages is called crawling or spidering
#need to download pages, pass to indexer (will build next)
#parse pages to find links to pages to be crawled next

import urllib.request

c = urllib.request.urlopen('http://en.wikipedia.org/wiki/Programming_language')
contents = c.read().decode('utf-8')
print(contents[:250])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Programming language - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(

# %%
#using beautiful soup you can build a crawler that likes a list of urls
#to index and crawl their links to find other pages to index

import bs4

#create a list of words to ignore
ignore_words = set(['the','of','to','and','a','in','is','it'])

# %%
#update the Crawler.crawl method

# %%
page_list = ['http://en.wikipedia.org/wiki/Programming_language']
crawler = Crawler('')
#crawler.crawl(page_list) #this runs forever

#loops through list of pages calling add_to_index on each one
#(which currently does nothing except print the URL)
#then uses BS to get all links on that page and adds their url
#to new_pages, at the end of the loop, new_pages becomes pages
#and the process begins again

#this is recursive so each links calls the function again
#BFS allows for easier modification of the code later, either to keep
#crawling forever or to save a list of unindexed pages for later crawling

# %%
#next step to build the database for the full-text index
#index is a list of all the different words along with the documents
#in which they appear and their locations in documents
#we will only be looking at text on page and ignoring non-text elements
#indexing words with all punctuation removed

#use SQLite to create a database
#instead of a server, stores in a single file

# %%
#change init, del and db_commit methods to open and close the db

# %%
#need to prepare the db
#need 5 tables
#url_list -> list of urls that have been indexed
#word_list -> list of words
#word_location -> list of locations of words in documents
#link and link_words -> links between documents
#link -> two URL IDs indicating a link from one table to another
#link_words -> uses word_id and link_id columns to store which words are
#  actually used in that link

#all tables in SQLiute have a field called rowid by default
#so no need to explicitly specify an ID for those tables

# %%
#update the create_index_tables method
#this will create a schema for all tables you will be using
#along with indices to speed up searching
#indices are important as dataset can get very large

# %%
#crawler = Crawler('search_index.db')
#crawler.create_index_tables()

# %%
#the files currently being downloaded are HTML so have a lot of tags
#and other information that doesn't belong in the index
#need to extract all parts of the page that aren't text

#do this by searching the soup for text nodes and collecting all of 
#their content

# %%
#update get_text_only method

#now returns a long string containing all the text on the page
#recursively traverses down the HTML document object model
#looking for text nodes
#text in separate sections is separated into different paragraphs
#need to preserve order

# %%
#update separate_words function

#splits a string into a list of separate words so they can be added to
#to the index
#it is very basic and considers everything non-alphanumberic to be a
#separator

# %%
#update add_to_index method

#now calls two functions defined previously to get list of words on the page
#then adds the page and all the words to the index
#and creates links between them with their locations in the document
#here, the location will be the index within the list of words

# %%
#update get_entry_id

#all this does is return ID of an entry if it exists, if not an ID
#is created and then returned

# %%
#update is_indexed

#finally need to fill in the code which determines whether the page
#is already in the database, and if so whether are are any words
#associated with it

# %%
crawler = Crawler('search_index.db')
pages = ['http://en.wikipedia.org/wiki/Programming_language']
crawler.crawl(pages)
# Out:
# /home/ben/miniconda3/envs/collective-intelligence/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/ben/miniconda3/envs/collective-intelligence/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# Indexing http://en.wikipedia.org/wiki/Programming_language
# /home/ben/miniconda3/envs/collective-intelligence/lib/python3.6/site-packages/ipykernel_launcher.py:69: FutureWarning: split() requires a non-empty pattern match.
# Indexing https://sr.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA
# Indexing http://www.ibm.com/developerworks/library/x-xslt/
# Indexing http://en.wikipedia.org/wiki/Declaration_(computer_science)
# Indexing http://en.wikipedia.org/w/index.php?title=Template:Programming_languages&action=edit
# Indexing http://en.wikipedia.org/wiki/Machine_instruction
# Indexing https://rue.wikipedia.org/wiki/%D0%AF%D0%B7%D1%8B%D0%BA_%D0%BF%D1%80%D0%BE%D2%91%D1%80%D0%B0%D0%BC%D0%BE%D0%B2%D0%B0%D0%BD%D1%8F
# Indexing http://en.wikipedia.org/wiki/Java_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Michael_Sipser
# Indexing https://de.wikipedia.org/wiki/Programmiersprache
# Could not open http://doi.org/10.1511%2F2006.60.299
# Indexing https://id.wikipedia.org/wiki/Bahasa_pemrograman
# Indexing http://en.wikipedia.org/wiki/XSLT
# Indexing http://en.wikipedia.org/wiki/File:Python_add5_parse.png
# Indexing http://en.wikipedia.org/wiki/Computer_science
# Could not open http://en.wikipedia.org/w/index.php?title=Christopher_T._Haynes&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/COBOL
# Indexing http://d-nb.info/gnd/4047409-4
# Indexing http://en.wikipedia.org/wiki/General-purpose_programming_language
# Indexing http://en.wikipedia.org/wiki/Lexical_analysis
# Indexing https://cv.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0_%D1%87%C4%95%D0%BB%D1%85%D0%B8
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-262-57095-5
# Indexing http://en.wikipedia.org/wiki/Input/output
# Indexing http://en.wikipedia.org/wiki/David_Gelernter
# Indexing https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%82%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE
# Indexing http://en.wikipedia.org/wiki/Unix
# Indexing http://en.wikipedia.org/wiki/File:8bit-dynamiclist_(reversed).gif
# Indexing http://en.wikipedia.org/wiki/Common_Language_Runtime
# Indexing http://en.wikipedia.org/wiki/Type_safety
# Indexing http://en.wikipedia.org/wiki/Domain-specific_language
# Indexing http://en.wikipedia.org/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Programming+language
# Indexing http://en.wikipedia.org/wiki/Esoteric_programming_language
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-12-633951-1
# Indexing http://en.wikipedia.org/w/index.php?title=Special:Log&type=review&page=Programming_language
# Indexing http://en.wikipedia.org/wiki/Ra%C3%BAl_Rojas
# Indexing http://en.wikipedia.org/wiki/Peter_Wegner
# Indexing https://bg.wikipedia.org/wiki/%D0%95%D0%B7%D0%B8%D0%BA_%D0%B7%D0%B0_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%B8%D1%80%D0%B0%D0%BD%D0%B5
# Indexing http://www.emu.edu.tr/aelci/Courses/D-318/D-318-Files/plbook/intro.htm
# Indexing http://en.wikipedia.org/wiki/Programming_languages_used_in_most_popular_websites
# Indexing https://wikimediafoundation.org/wiki/Privacy_policy
# Indexing http://en.wikipedia.org/wiki/Reference_implementation_(computing)
# Indexing http://en.wikipedia.org/wiki/Category:Lists_of_computer_languages
# Indexing https://el.wikipedia.org/wiki/%CE%93%CE%BB%CF%8E%CF%83%CF%83%CE%B1_%CF%80%CF%81%CE%BF%CE%B3%CF%81%CE%B1%CE%BC%CE%BC%CE%B1%CF%84%CE%B9%CF%83%CE%BC%CE%BF%CF%8D
# Indexing http://en.wikipedia.org/wiki/Markup_language
# Indexing http://en.wikipedia.org/wiki/Fourth-generation_programming_language
# Indexing http://en.wikipedia.org/wiki/Evaluation_strategy
# Could not open http://en.wikipedia.org/w/index.php?title=Bruce_J._MacLennan&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_GND_identifiers
# Indexing https://jv.wikipedia.org/wiki/Basa_pamrograman
# Indexing http://en.wikipedia.org/wiki/Jacquard_loom
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=16
# Indexing http://en.wikipedia.org/wiki/FLOW-MATIC
# Could not open https://id.ndl.go.jp/auth/ndlna/00569224
# Indexing http://en.wikipedia.org/wiki/Fifth_generation_programming_language
# Indexing http://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Programming_language&id=802689990
# Indexing https://tr.wikipedia.org/wiki/Programlama_dili
# Indexing http://en.wikipedia.org/wiki/Morgan_Kaufmann_Publishers
# Indexing https://ga.wikipedia.org/wiki/Teanga_r%C3%ADomhchl%C3%A1r%C3%BAch%C3%A1in
# Could not open http://hopl.murdoch.edu.au/
# Indexing http://en.wikipedia.org/wiki/Reference_implementation
# Indexing http://en.wikipedia.org/wiki/Lua_(programming_language)
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&printable=yes
# Indexing http://en.wikipedia.org/wiki/KL1
# Indexing http://en.wikipedia.org/wiki/Computer_program
# Indexing http://en.wikipedia.org/wiki/Main_Page
# Indexing http://en.wikipedia.org/wiki/Programmer
# Indexing https://arz.wikipedia.org/wiki/%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D9%87
# Indexing http://en.wikipedia.org/wiki/EDSAC
# Indexing https://kk.wikipedia.org/wiki/%D0%91%D0%B0%D2%93%D0%B4%D0%B0%D1%80%D0%BB%D0%B0%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D1%96%D0%BB%D1%96
# Indexing http://www.jeffreykegler.com/Home/perl-and-undecidability
# Indexing http://en.wikipedia.org/wiki/Visual_programming_language
# Indexing http://en.wikipedia.org/wiki/C_Sharp_(programming_language)
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=24
# Indexing http://en.wikipedia.org/wiki/Functional_programming
# Indexing http://en.wikipedia.org/wiki/Edsger_W._Dijkstra
# Indexing http://en.wikipedia.org/wiki/List_of_programming_languages_by_type
# Indexing http://en.wikipedia.org/wiki/Data_type
# Indexing http://www.mediawiki.org/
# Indexing http://en.wikipedia.org/wiki/Formal_specification
# Indexing http://data.bnf.fr/ark:/12148/cb13318353n
# Indexing http://en.wikipedia.org/wiki/Interpreted_language
# Indexing http://en.wikipedia.org/wiki/Modeling_language
# Indexing http://en.wikipedia.org/wiki/ALGOL_60
# Could not open http://en.wikipedia.org/w/index.php?title=Terrence_W._Pratt&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Software_bug
# Indexing http://en.wikipedia.org/wiki/Scientific_programming_language
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-07-222942-X
# Indexing http://dblp.uni-trier.de/db/conf/icsoft/icsoft2007-1.html
# Indexing https://sl.wikipedia.org/wiki/Programski_jezik
# Indexing http://en.wikipedia.org/wiki/Non-English-based_programming_languages
# Indexing https://af.wikipedia.org/wiki/Programmeertaal
# Indexing http://en.wikipedia.org/wiki/Colorless_green_ideas_sleep_furiously
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-19-511306-3
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=22
# Indexing http://en.wikipedia.org/wiki/Declarative_programming
# Indexing http://en.wikipedia.org/wiki/Structured_programming
# Indexing http://en.wikipedia.org/wiki/Weak_typing
# Indexing http://en.wikipedia.org/wiki/Alan_Jeffrey
# Indexing http://www.cs.brown.edu/people/tld/courses/cs148/02/programming.html
# Indexing https://wikimediafoundation.org/wiki/Cookie_statement
# Indexing http://en.wikipedia.org/w/index.php?title=Special:ElectronPdf&page=Programming+language&action=show-selection-screen&coll-download-url=%2Fw%2Findex.php%3Ftitle%3DSpecial%3ABook%26bookcmd%3Drender_article%26arttitle%3DProgramming%2Blanguage%26returnto%3DProgramming%2Blanguage%26oldid%3D802689990%26writer%3Drdf2latex
# Indexing http://en.wikipedia.org/wiki/Special:RecentChangesLinked/Programming_language
# Indexing http://en.wikipedia.org/wiki/Addison-Wesley
# Indexing http://en.wikipedia.org/wiki/Synchronous_programming_language
# Indexing http://en.wikipedia.org/wiki/Ellis_Horowitz
# Indexing https://su.wikipedia.org/wiki/Basa_program
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=14
# Could not open http://www.apl.jhu.edu/~hall/Lisp-Notes/Macros.ps
# Indexing http://en.wikipedia.org/wiki/Type_theory
# Indexing http://mitpress.mit.edu/sicp/full-text/book/book-Z-H-4.html
# Indexing http://en.wikipedia.org/wiki/Dataflow_programming
# Indexing http://en.wikipedia.org/wiki/First-generation_programming_language
# Indexing http://en.wikipedia.org/wiki/Template_talk:Programming_languages
# Indexing http://en.wikipedia.org/wiki/Compiled
# Indexing http://en.wikipedia.org/wiki/Standard_Generalized_Markup_Language
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# Indexing http://en.wikipedia.org/wiki/Turing_completeness
# Indexing http://en.wikipedia.org/wiki/Swift_(programming_language)
# Indexing https://lv.wikipedia.org/wiki/Programm%C4%93%C5%A1anas_valoda
# Indexing http://en.wikipedia.org/wiki/Atlas_Computer_(Manchester)
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=11
# Indexing https://sco.wikipedia.org/wiki/Programmin_leid
# Indexing http://en.wikipedia.org/wiki/English_language
# Indexing http://en.wikipedia.org/wiki/File:Python_add5_syntax.svg
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=20
# Indexing http://en.wikipedia.org/wiki/Microcontroller
# Indexing http://en.wikipedia.org/wiki/Context-free_grammar
# Indexing http://en.wikipedia.org/wiki/Architecture_description_language
# Indexing http://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements
# Indexing http://en.wikipedia.org/wiki/Array_programming
# Indexing http://en.wikipedia.org/wiki/Programming_Languages:_Application_and_Interpretation
# Indexing http://en.wikipedia.org/wiki/Michael_L._Scott
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=info
# Could not open http://en.wikipedia.org/w/index.php?title=Mark_Sheldon&action=edit&redlink=1
# Indexing https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%8D%E0%B0%B0%E0%B1%8B%E0%B0%97%E0%B1%8D%E0%B0%B0%E0%B0%BE%E0%B0%AE%E0%B0%BF%E0%B0%82%E0%B0%97%E0%B1%81_%E0%B0%AD%E0%B0%BE%E0%B0%B7
# Indexing https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE
# Indexing https://sv.wikipedia.org/wiki/Programspr%C3%A5k
# Indexing http://en.wikipedia.org/wiki/Punched_card
# Indexing http://en.wikipedia.org/wiki/Definite_assignment_analysis
# Indexing http://en.wikipedia.org/wiki/Prototype-based_programming
# Indexing http://en.wikipedia.org/wiki/Hardware_description_language
# Indexing http://en.wikipedia.org/wiki/John_Mauchly
# Indexing http://en.wikipedia.org/wiki/Instruction_set_architecture
# Indexing http://en.wikipedia.org/wiki/Association_for_Computing_Machinery
# Indexing http://en.wikipedia.org/wiki/Benjamin_C._Pierce
# Indexing http://en.wikipedia.org/wiki/Software_engineering
# Indexing http://en.wikipedia.org/wiki/Object-oriented_programming
# Indexing http://en.wikipedia.org/wiki/Markup_languages
# Indexing https://et.wikipedia.org/wiki/Programmeerimiskeel
# Indexing https://lb.wikipedia.org/wiki/Programm%C3%A9iersprooch
# Indexing http://en.wikipedia.org/wiki/Templating_language
# Indexing http://en.wikipedia.org/wiki/Language_primitive
# Indexing https://is.wikipedia.org/wiki/Forritunarm%C3%A1l
# Indexing http://en.wikipedia.org/wiki/Chomsky_hierarchy
# Indexing http://en.wikipedia.org/wiki/Alick_Glennie
# Indexing https://kab.wikipedia.org/wiki/Timeslayin_n_usihel
# Could not open http://queue.acm.org/detail.cfm?id=1820518
# Indexing http://en.wikipedia.org/wiki/Rule-based_system
# Indexing http://shop.wikimedia.org
# Indexing https://bug.wikipedia.org/wiki/%E1%A8%85%E1%A8%94_%E1%A8%80%E1%A8%9A%E1%A8%87%E1%A8%98%E1%A8%88%E1%A8%9B%E1%A8%91%E1%A8%9B
# Indexing http://en.wikipedia.org/wiki/Abstraction_principle_(programming)
# Indexing http://en.wikipedia.org/wiki/Plankalk%C3%BCl
# Could not open http://en.wikipedia.org/w/index.php?title=Franklyn_Turbak&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Category:Programming_languages
# Indexing https://no.wikipedia.org/wiki/Programmeringsspr%C3%A5k
# Indexing https://ast.wikipedia.org/wiki/Llinguaxe_de_programaci%C3%B3n
# Indexing http://en.wikipedia.org/wiki/Electronic_computer
# Indexing http://en.wikipedia.org/wiki/Algorithm
# Indexing http://en.wikipedia.org/wiki/Integrated_Authority_File
# Indexing http://en.wikipedia.org/wiki/BASIC
# Indexing http://en.wikipedia.org/wiki/Halting_problem
# Indexing http://www.wikimediafoundation.org/
# Indexing http://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_July_2015
# Indexing https://mwl.wikipedia.org/wiki/Lenguaige_de_porgrama%C3%A7on
# Indexing http://en.wikipedia.org/wiki/SQL-92
# Indexing http://en.wikipedia.org/wiki/Procedural_programming
# Indexing http://en.wikipedia.org/wiki/W3C
# Indexing http://en.wikipedia.org/wiki/Rice%27s_theorem
# Indexing https://cy.wikipedia.org/wiki/Iaith_rhaglennu
# Indexing https://sah.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D0%B0h%D1%8B%D0%BD_%D1%82%D1%8B%D0%BB%D0%B0
# Indexing http://en.wikipedia.org/wiki/Type_declaration
# Indexing http://en.wikipedia.org/wiki/Compiler
# Indexing http://en.wikipedia.org/wiki/Timeline_of_programming_languages
# Indexing http://en.wikipedia.org/wiki/Metaprogramming
# Indexing http://en.wikipedia.org/wiki/Daniel_P._Friedman
# Indexing http://en.wikipedia.org/wiki/MATLAB
# Indexing http://www.seas.upenn.edu/~sweirich/types/archive/1999-2003/msg00849.html
# Indexing http://en.wikipedia.org/wiki/XML
# Indexing http://en.wikipedia.org/wiki/Null_pointer
# Indexing https://my.wikipedia.org/wiki/Programming_language
# Indexing http://en.wikipedia.org/wiki/Write_once,_run_anywhere
# Indexing http://www.schemers.org/Documents/Standards/R5RS/HTML/r5rs-Z-H-10.html
# Indexing http://en.wikipedia.org/wiki/Virtual_machine
# Indexing http://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Programming+language
# Indexing http://en.wikipedia.org/wiki/Front_panel
# Indexing http://en.wikipedia.org/wiki/Abstraction_(computer_science)
# Indexing http://en.wikipedia.org/wiki/Syntax_(programming_languages)
# Indexing http://en.wikipedia.org/wiki/Extensible_programming
# Indexing http://en.wikipedia.org/wiki/Syntax_highlighting
# Indexing http://en.wikipedia.org/wiki/Program_(machine)
# Indexing http://www.cs.utexas.edu/users/EWD/ewd02xx/EWD215.PDF
# Indexing https://bat-smg.wikipedia.org/wiki/Pruogramav%C4%97ma_kalba
# Indexing https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n
# Could not open http://www.acm.org/sigs/sigplan/sigplan_bylaws.htm
# Indexing https://ba.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D0%B5%D0%BB%D0%B5
# Indexing http://en.wikipedia.org/wiki/Macro_(computer_science)
# Indexing https://tt.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D0%B5%D0%BB%D0%B5
# Indexing http://en.wikipedia.org/wiki/Educational_programming_language
# Indexing http://pll.cpsc.ucalgary.ca/charity1/www/home.html
# Indexing http://en.wikipedia.org/wiki/Regular_expression
# Indexing http://en.wikipedia.org/wiki/Ruby_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Microsoft
# Indexing https://hu.wikipedia.org/wiki/Programoz%C3%A1si_nyelv
# Indexing http://en.wikipedia.org/wiki/Help:Contents
# Indexing http://en.wikipedia.org/wiki/Niklaus_Wirth
# Indexing http://en.wikipedia.org/wiki/History_of_computing_hardware
# Indexing http://en.wikipedia.org/wiki/Control_flow
# Could not open http://doi.acm.org/10.1145/2745802.2745805
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=history
# Indexing https://mhr.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%BB%D1%8B%D0%BC%D0%B0%D1%88_%D0%B9%D1%8B%D0%BB%D0%BC%D0%B5
# Indexing http://en.wikipedia.org/wiki/Undefined_behavior
# Indexing http://en.wikipedia.org/wiki/Ravi_Sethi
# Indexing http://en.wikipedia.org/wiki/Peter_H._Salus
# Indexing https://la.wikipedia.org/wiki/Lingua_programmandi
# Indexing http://en.wikipedia.org/wiki/Oracle_America,_Inc._v._Google,_Inc.
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=5
# Indexing https://zh-yue.wikipedia.org/wiki/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80
# Indexing http://en.wikipedia.org/wiki/Robin_Milner
# Indexing http://en.wikipedia.org/wiki/Gerald_Jay_Sussman
# Indexing https://uk.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%83%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=15
# Indexing https://an.wikipedia.org/wiki/Luengache_de_programaci%C3%B3n
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=4
# Indexing http://en.wikipedia.org/wiki/File:C_Hello_World_Program.png
# Indexing https://als.wikipedia.org/wiki/Programmiersprache
# Indexing http://en.wikipedia.org/wiki/Visual_Basic_.NET
# Indexing https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E8%A8%80%E8%AA%9E
# Indexing http://en.wikipedia.org/wiki/Internet
# Indexing http://www.mactech.com/articles/mactech/Vol.15/15.09/ScriptingLanguages/index.html
# Indexing https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%81%E0%B8%81%E0%B8%A3%E0%B8%A1
# Indexing http://en.wikipedia.org/wiki/Printer_(computing)
# Indexing http://en.wikipedia.org/wiki/Exception_handling
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=21
# Indexing http://en.wikipedia.org/wiki/Comparison_of_programming_languages
# Indexing https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE
# Indexing http://en.wikipedia.org/wiki/Morgan_Kaufmann
# Indexing http://en.wikipedia.org/wiki/Smalltalk
# Indexing https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90
# Indexing http://en.wikipedia.org/wiki/High-performance_computing
# Indexing http://tunes.org/wiki/programming_20languages.html
# Indexing http://en.wikipedia.org/wiki/Template:Programming_languages
# Indexing http://en.wikipedia.org/wiki/University_of_Cambridge_Mathematical_Laboratory
# Indexing http://en.wikipedia.org/wiki/Special:SpecialPages
# Indexing http://en.wikipedia.org/wiki/Template:Types_of_programming_languages
# Indexing http://en.wikipedia.org/wiki/Category:Wikipedia_pending_changes_protected_pages_(level_1)
# Indexing http://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# Indexing https://nn.wikipedia.org/wiki/Programmeringsspr%C3%A5k
# Indexing http://en.wikipedia.org/wiki/APL_(programming_language)
# Indexing https://sq.wikipedia.org/wiki/Gjuh%C3%AB_programimi
# Indexing http://en.wikipedia.org/wiki/Batch_processing
# Indexing http://en.wikipedia.org/wiki/Event-driven_programming
# Indexing http://en.wikipedia.org/wiki/John_Backus
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-387-95217-9
# Indexing http://en.wikipedia.org/w/index.php?title=Template:Types_of_programming_languages&action=edit
# Indexing http://msdn.microsoft.com/en-us/library/ms767587(VS.85).aspx
# Indexing http://en.wikipedia.org/wiki/Portal:Current_events
# Indexing http://en.m.wikipedia.org/w/index.php?title=Programming_language&mobileaction=toggle_view_mobile
# Indexing http://en.wikipedia.org/wiki/Lists_of_programming_languages
# Indexing http://www.acooke.org/comp-lang.html
# Indexing https://war.wikipedia.org/wiki/Pinulongan_hin_programa
# Indexing https://diq.wikipedia.org/wiki/Z%C4%B1wan%C3%AA_programnay%C4%B1%C5%9Fi
# Indexing http://en.wikipedia.org/wiki/Cambridge_University_Press
# Indexing http://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_BNF_identifiers
# Indexing http://en.wikipedia.org/wiki/Ban%C5%AB_M%C5%ABs%C4%81
# Indexing http://en.wikipedia.org/wiki/List_of_software_engineering_topics
# Indexing http://en.wikipedia.org/wiki/Command-line_interface
# Could not open http://doi.org/10.1145%2F154766.155378
# Indexing http://en.wikipedia.org/wiki/Run_time_(program_lifecycle_phase)
# Indexing http://en.wikipedia.org/wiki/Source_code
# Indexing http://en.wikipedia.org/wiki/Alan_Perlis
# Indexing https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o
# Indexing http://en.wikipedia.org/wiki/Ada_(programming_language)
# Indexing https://pl.wikipedia.org/wiki/J%C4%99zyk_programowania
# Indexing https://km.wikipedia.org/wiki/%E1%9E%97%E1%9E%B6%E1%9E%9F%E1%9E%B6%E1%9E%80%E1%9E%98%E1%9F%92%E1%9E%98%E1%9E%9C%E1%9E%B7%E1%9E%92%E1%9E%B8
# Indexing https://azb.wikipedia.org/wiki/%DB%8C%D8%A7%D8%B2%DB%8C%D9%84%DB%8C%D9%85%D9%84%D8%A7%D9%85%D8%A7_%D8%AF%DB%8C%D9%84%DB%8C
# Indexing http://www.seas.upenn.edu/~sweirich/types/archive/1999-2003/msg00921.html
# Indexing http://en.wikipedia.org/wiki/Type_conversion
# Indexing http://readscheme.org/modules/
# Indexing http://www.levenez.com/lang/
# Indexing https://bar.wikipedia.org/wiki/Programmiasproch
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=23
# Indexing http://en.wikipedia.org/wiki/Fifth-generation_programming_language
# Indexing http://en.wikipedia.org/wiki/American_National_Standards_Institute
# Indexing https://io.wikipedia.org/wiki/Programifo-lingui
# Indexing http://en.wikipedia.org/wiki/Case_statement
# Indexing https://bs.wikipedia.org/wiki/Programski_jezik
# Indexing http://en.wikipedia.org/wiki/Wikipedia:About
# Indexing http://en.wikipedia.org/wiki/Parse_tree
# Could not open http://en.wikipedia.org/w/index.php?title=Suresh_Jagannathan&action=edit&redlink=1
# Indexing https://ie.wikipedia.org/wiki/Lingua_de_programmation
# Indexing http://en.wikipedia.org/wiki/Objective-C
# Indexing https://en.wikiquote.org/wiki/Programming_languages
# Indexing http://en.wikipedia.org/wiki/UNCOL
# Indexing http://en.wikipedia.org/wiki/Just-in-time_compilation
# Indexing http://en.wikipedia.org/wiki/Autocode
# Indexing http://en.wikipedia.org/wiki/Simula
# Indexing http://en.wikipedia.org/wiki/PostScript
# Indexing http://en.wikipedia.org/wiki/Standard_library
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&oldid=802689990
# Could not open http://doi.org/10.1145%2F362929.362947
# Indexing http://en.wikipedia.org/wiki/Very_high-level_programming_language
# Indexing http://en.wikipedia.org/wiki/Manchester_Mark_1
# Indexing http://en.wikipedia.org/wiki/JavaScript
# Indexing http://en.wikipedia.org/wiki/Data_flow_analysis
# Indexing http://en.wikipedia.org/wiki/Multi-paradigm_programming_language
# Indexing http://en.wikipedia.org/wiki/Atlas_Autocode
# Indexing http://en.wikipedia.org/wiki/Types_and_Programming_Languages
# Indexing https://zh.wikipedia.org/wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80
# Indexing http://en.wikipedia.org/wiki/Grace_Hopper
# Indexing http://www.netlib.org/benchmark/hpl
# Indexing http://en.wikipedia.org/wiki/Style_sheet_language
# Could not open http://www.computerweekly.com/Articles/2007/09/11/226631/sslcomputer-weekly-it-salary-survey-finance-boom-drives-it-job.htm
# Indexing https://www.wikidata.org/wiki/Q9143
# Indexing https://vi.wikipedia.org/wiki/Ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh
# Indexing http://en.wikipedia.org/wiki/Edsger_Dijkstra
# Indexing http://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references
# Indexing http://en.wikipedia.org/wiki/Shell_script
# Indexing https://oc.wikipedia.org/wiki/Lengatge_de_programacion
# Indexing http://www.cs.cornell.edu/info/Projects/Nuprl/cs611/fall94notes/cn2/subsection3_1_3.html
# Indexing http://en.wikipedia.org/wiki/Command_(computing)
# Indexing http://en.wikipedia.org/w/index.php?title=Template:Computer_language&action=edit
# Indexing https://nl.wikipedia.org/wiki/Programmeertaal
# Indexing http://en.wikipedia.org/wiki/Mitchell_Wand
# Indexing http://en.wikipedia.org/wiki/Java_programming_language
# Indexing http://en.wikipedia.org/wiki/John_C._Reynolds
# Indexing http://en.wikipedia.org/wiki/Unix_shell
# Indexing http://en.wikipedia.org/wiki/Thread_(computer_science)
# Indexing http://en.wikipedia.org/wiki/Formal_language
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=25
# Indexing http://en.wikipedia.org/wiki/Goto
# Indexing https://ar.wikipedia.org/wiki/%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D8%A9
# Indexing http://en.wikipedia.org/wiki/David_A._Watt
# Indexing https://ro.wikipedia.org/wiki/Limbaj_de_programare
# Indexing http://en.wikipedia.org/wiki/String_literal
# Indexing http://en.wikipedia.org/wiki/Computer_Programming
# Could not open http://en.wikipedia.org/w/index.php?title=Marvin_V._Zelkowitz&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Protection_policy
# Indexing http://en.wikipedia.org/wiki/Concepts,_Techniques,_and_Models_of_Computer_Programming
# Indexing https://mn.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%87%D0%BB%D0%B0%D0%BB%D1%8B%D0%BD_%D1%85%D1%8D%D0%BB
# Indexing http://en.wikipedia.org/wiki/Type_system
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/9780199693795
# Indexing http://en.wikipedia.org/wiki/History_of_programming_languages
# Indexing http://www.computerworld.com.au/article/319269/cobol_turns_50/
# Indexing http://en.wikipedia.org/wiki/Modula-2
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=1
# Indexing http://catalogue.bnf.fr/ark:/12148/cb13318353n
# Indexing http://www.cs.brown.edu/~sk/Publications/Books/ProgLangs/
# Indexing http://en.wikipedia.org/wiki/Portal:Computer_programming
# Indexing http://en.wikipedia.org/wiki/Scripting_language
# Indexing http://en.wikipedia.org/wiki/Anonymous_function
# Indexing http://mitpress.mit.edu/sicp/full-text/book/book-Z-H-10.html
# Indexing http://en.wikipedia.org/wiki/Tcl
# Indexing http://en.wikipedia.org/wiki/The_MIT_Press
# Indexing http://en.wikipedia.org/wiki/File:Bangalore_India_Tech_books_for_sale_IMG_5261.jpg
# Indexing https://jbo.wikipedia.org/wiki/samplabau
# Indexing https://ru.wikipedia.org/wiki/%D0%AF%D0%B7%D1%8B%D0%BA_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F
# Indexing http://en.wikipedia.org/wiki/Kotlin_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Compile_time
# Indexing http://en.wikipedia.org/wiki/Template:Computer_language
# Indexing http://en.wikipedia.org/wiki/Charity_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-262-63181-4
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-89791-570-4
# Indexing https://da.wikipedia.org/wiki/Programmeringssprog
# Indexing http://en.wikipedia.org/wiki/Help:CS1_errors
# Indexing https://uz.wikipedia.org/wiki/Programmalash_tili
# Indexing https://br.wikipedia.org/wiki/Yezh_programmi%C3%B1
# Indexing https://cs.wikipedia.org/wiki/Programovac%C3%AD_jazyk
# Indexing http://en.wikipedia.org/wiki/List_of_programming_languages
# Indexing https://cdo.wikipedia.org/wiki/Pi%C4%95ng-ti%C3%A0ng_ng%E1%B9%B3%CC%84-ngi%C3%B2ng
# Indexing http://en.wikipedia.org/wiki/AIMACO
# Indexing https://he.wikipedia.org/wiki/%D7%A9%D7%A4%D7%AA_%D7%AA%D7%9B%D7%A0%D7%95%D7%AA
# Indexing https://fa.wikipedia.org/wiki/%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C
# Indexing https://mk.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA
# Indexing http://en.wikipedia.org/wiki/Player_piano
# Indexing http://en.wikipedia.org/wiki/Generational_list_of_programming_languages
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=12
# Indexing http://en.wikipedia.org/wiki/Help:Authority_control
# Indexing http://en.wikipedia.org/wiki/List_of_programming_language_researchers
# Indexing http://en.wikipedia.org/wiki/Dialect_(computing)
# Indexing http://en.wikipedia.org/wiki/Erlang_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Islamic_Golden_Age
# Indexing http://en.wikipedia.org/wiki/Natural_language
# Indexing http://www.cs.berkeley.edu/~flab/languages.html
# Indexing http://en.wikipedia.org/wiki/Language_Integrated_Query
# Indexing http://en.wikipedia.org/wiki/Martin_Odersky
# Indexing http://www.encyclopediaofmath.org/index.php?title=PL/I&oldid=19175
# Could not open http://doi.org/10.1145%2F2745802.2745805
# Indexing https://be.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-262-19349-3
# Indexing http://www.cs.utexas.edu/users/EWD/transcriptions/EWD06xx/EWD667.html
# Indexing http://en.wikipedia.org/wiki/Mads_Tofte
# Indexing http://en.wikipedia.org/wiki/Second-generation_programming_language
# Indexing http://en.wikipedia.org/wiki/Fortran
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-12-012108-5
# Indexing http://en.wikipedia.org/wiki/System_programming_language
# Indexing http://en.wikipedia.org/wiki/Interpreter_(computing)
# Indexing http://en.wikipedia.org/wiki/Supercomputer
# Indexing http://en.wikipedia.org/wiki/National_Diet_Library
# Indexing http://en.wikipedia.org/wiki/Session_(computer_science)
# Indexing https://sh.wikipedia.org/wiki/Programski_jezik
# Indexing https://ne.wikipedia.org/wiki/%E0%A4%95%E0%A4%AE%E0%A5%8D%E0%A4%AA%E0%A5%8D%E0%A4%AF%E0%A5%81%E0%A4%9F%E0%A4%B0_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE
# Indexing https://en.wikibooks.org/wiki/Subject:Computer_programming_languages
# Could not open http://en.wikipedia.org/w/index.php?title=Robert_W._Sebesta&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/SQL
# Indexing http://en.wikipedia.org/wiki/C_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Lisp_macro
# Could not open http://en.wikipedia.org/w/index.php?title=Peter_Van_Roy&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Constructed_languages
# Indexing http://en.wikipedia.org/wiki/REXX
# Indexing http://en.wikipedia.org/wiki/Go_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Machine_code
# Indexing http://en.wikipedia.org/wiki/Reflection_(computer_programming)
# Indexing http://en.wikipedia.org/wiki/Programming_paradigm
# Indexing http://en.wikipedia.org/wiki/LaTeX
# Indexing http://en.wikipedia.org/wiki/Short_Code_(computer_language)
# Indexing https://hr.wikipedia.org/wiki/Programski_jezik
# Indexing http://en.wikipedia.org/wiki/Mixin
# Indexing http://en.wikipedia.org/wiki/Aspect-oriented_programming
# Indexing https://fi.wikipedia.org/wiki/Ohjelmointikieli
# Indexing http://en.wikipedia.org/wiki/Computer
# Indexing https://pa.wikipedia.org/wiki/%E0%A8%AA%E0%A9%8D%E0%A8%B0%E0%A9%8B%E0%A8%97%E0%A8%B0%E0%A8%BE%E0%A8%AE%E0%A8%BF%E0%A9%B0%E0%A8%97_%E0%A8%AD%E0%A8%BE%E0%A8%B8%E0%A8%BC%E0%A8%BE
# Indexing https://tobi.oetiker.ch/lshort/lshort.pdf
# Indexing http://en.wikipedia.org/wiki/Python_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Concurrent_computing
# Indexing http://www.math.grin.edu/~rebelsky/Courses/CS302/99S/Outlines/outline.02.html
# Indexing https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A5%85%E0%A4%AE%E0%A4%BF%E0%A4%82%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE
# Indexing https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# Indexing http://en.wikipedia.org/wiki/TOP500
# Indexing http://en.wikipedia.org/wiki/Portal:Contents
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/978-1-4503-3350-4
# Indexing http://en.wikipedia.org/wiki/Data-structured_language
# Indexing http://en.wikipedia.org/wiki/Category:Lists_of_programming_languages
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=6
# Indexing https://ilo.wikipedia.org/wiki/Lengguahe_ti_panangprograma
# Indexing http://en.wikipedia.org/wiki/Prolog
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=17
# Indexing http://en.wikipedia.org/wiki/Comparison_of_programming_languages_(basic_instructions)
# Could not open https://books.google.com/books?id=kpYX_lNI0VMC
# Indexing https://eu.wikipedia.org/wiki/Programazio-lengoaia
# Indexing http://en.wikipedia.org/wiki/Semantics_of_programming_languages
# Indexing http://en.wikipedia.org/wiki/Scheme_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Talk:Programming_language
# Indexing http://en.wikipedia.org/wiki/UNIVAC_I
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=2
# Could not open http://www.langpop.com/
# Indexing http://en.wikipedia.org/wiki/Oxford_University_Press
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-262-16209-1
# Indexing http://en.wikipedia.org/wiki/Library_of_Congress_Control_Number
# Indexing http://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# Could not open http://www.nondot.org/sabre/Mirrored/AdvProgLangDesign/
# Indexing http://en.wikipedia.org/wiki/Essentials_of_Programming_Languages
# Indexing http://en.wikipedia.org/wiki/Programming_language_theory
# Indexing https://hsb.wikipedia.org/wiki/Program%C4%9Browanske_r%C4%9B%C4%8De
# Indexing https://xmf.wikipedia.org/wiki/%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%90%E1%83%A4%E1%83%90%E1%83%A8_%E1%83%9C%E1%83%98%E1%83%9C%E1%83%90
# Indexing http://en.wikipedia.org/wiki/Actor_model
# Indexing http://en.wikipedia.org/wiki/Category:Notation
# Indexing https://ko.wikipedia.org/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_%EC%96%B8%EC%96%B4
# Indexing https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8D%95%E1%88%AE%E1%8C%8D%E1%88%AB%E1%88%9D_%E1%89%8B%E1%8A%95%E1%89%8B
# Indexing http://en.wikipedia.org/wiki/High-level_language
# Indexing http://en.wikipedia.org/wiki/Invariant_based_programming
# Indexing http://en.wikipedia.org/wiki/Introduction_to_the_Theory_of_Computation
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=7
# Indexing http://en.wikipedia.org/wiki/Subroutine
# Indexing http://en.wikipedia.org/wiki/Identifier
# Indexing http://en.wikipedia.org/wiki/Mainframe_computer
# Indexing http://en.wikipedia.org/wiki/Help:Maintenance_template_removal
# Indexing http://citeseer.ist.psu.edu/cardelli85understanding.html
# Indexing http://en.wikipedia.org/wiki/FORTRAN
# Indexing http://en.wikipedia.org/wiki/Third-generation_programming_language
# Indexing https://lt.wikipedia.org/wiki/Programavimo_kalba
# Indexing http://en.wikipedia.org/wiki/Category:CS1_maint:_Multiple_names:_authors_list
# Indexing http://en.wikipedia.org/wiki/Library_(computing)
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=13
# Indexing http://en.wikipedia.org/wiki/String_(computer_science)
# Indexing http://en.wikipedia.org/wiki/VBScript
# Indexing http://en.wikipedia.org/wiki/Assembly_language
# Indexing https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%82%E0%B4%97%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7
# Could not open http://en.wikipedia.org/w/index.php?title=Seif_Haridi&action=edit&redlink=1
# Indexing http://en.wikipedia.org/wiki/Computer_programming
# Indexing http://en.wikipedia.org/wiki/Manifest_typing
# Indexing http://en.wikipedia.org/wiki/Z3_(computer)
# Indexing http://en.wikipedia.org/wiki/Lisp_(programming_language)
# Indexing https://ta.wikipedia.org/wiki/%E0%AE%A8%E0%AE%BF%E0%AE%B0%E0%AE%B2%E0%AF%8D_%E0%AE%AE%E0%AF%8A%E0%AE%B4%E0%AE%BF
# Indexing http://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_April_2012
# Indexing http://www.contrib.andrew.cmu.edu/~shadow/sql/sql1992.txt
# Indexing https://sk.wikipedia.org/wiki/Programovac%C3%AD_jazyk
# Could not open http://www.icot.or.jp/ARCHIVE/HomePage-E.html
# Indexing http://en.wikipedia.org/wiki/Type_inference
# Indexing http://en.wikipedia.org/wiki/Backus%E2%80%93Naur_form
# Indexing https://hy.wikipedia.org/wiki/%D4%BE%D6%80%D5%A1%D5%A3%D6%80%D5%A1%D5%BE%D5%B8%D6%80%D5%B4%D5%A1%D5%B6_%D5%AC%D5%A5%D5%A6%D5%B8%D6%82
# Could not open http://en.wikipedia.org/w/index.php?title=David_Gifford&action=edit&redlink=1
# Indexing https://ia.wikipedia.org/wiki/Linguage_de_programmation
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=9
# Indexing http://en.wikipedia.org/wiki/Static_code_analysis
# Indexing http://en.wikipedia.org/wiki/Help:Category
# Indexing http://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# Could not open http://www.w3.org/XML/1999/XML-in-10-points.html
# Indexing http://en.wikipedia.org/wiki/Bytecode
# Indexing http://en.wikipedia.org/wiki/Dynamic_programming_language
# Indexing http://wikimediafoundation.org/wiki/Privacy_policy
# Indexing https://az.wikipedia.org/wiki/Proqramla%C5%9Fd%C4%B1rma_dill%C9%99ri
# Indexing http://www.schemers.org/Documents/Standards/R5RS/HTML/r5rs-Z-H-4.html
# Indexing http://en.wikipedia.org/wiki/International_Standard_Book_Number
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Citing_sources
# Indexing https://nds.wikipedia.org/wiki/Programmeerspraak
# Indexing http://en.wikipedia.org/wiki/Portal:Featured_content
# Indexing https://tl.wikipedia.org/wiki/Wikang_pamprograma
# Indexing https://ur.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%86%DA%AF_%D8%B2%D8%A8%D8%A7%D9%86
# Indexing http://en.wikipedia.org/wiki/Forth_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Robert_Harper_(computer_scientist)
# Indexing http://en.wikipedia.org/wiki/Murdoch_University
# Indexing https://en.wiktionary.org/wiki/programming_language
# Indexing https://ckb.wikipedia.org/wiki/%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D8%A8%DB%95%D8%B1%D9%86%D8%A7%D9%85%DB%95%D8%B3%D8%A7%D8%B2%DB%8C
# Indexing http://en.wikipedia.org/wiki/Concatenative_programming_language
# Indexing http://en.wikipedia.org/wiki/Literate_programming
# Indexing http://en.wikipedia.org/wiki/David_Hartley_(computer_scientist)
# Indexing http://en.wikipedia.org/wiki/Transformation_language
# Indexing http://en.wikipedia.org/wiki/Special:RecentChanges
# Could not open http://creativecommons.org/licenses/by-sa/3.0/
# Indexing http://en.wikipedia.org/wiki/Compiled_language
# Indexing http://en.wikipedia.org/wiki/Harold_Abelson
# Indexing http://en.wikipedia.org/wiki/Pseudocode
# Indexing http://en.wikipedia.org/wiki/Decidability_(logic)
# Indexing http://en.wikipedia.org/wiki/Robot
# Indexing http://en.wikipedia.org/wiki/Measuring_programming_language_popularity
# Indexing http://en.wikipedia.org/wiki/Domain-specific_programming_language
# Indexing http://en.wikipedia.org/wiki/Portal:Computer_science
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/81-224-1379-X
# Indexing http://en.wikipedia.org/wiki/Template_talk:Computer_language
# Indexing http://en.wikipedia.org/wiki/Raphael_Finkel
# Indexing http://en.wikipedia.org/wiki/File:Question_book-new.svg
# Indexing http://en.wikipedia.org/wiki/Generic_programming
# Indexing http://en.wikipedia.org/wiki/Special:MyContributions
# Indexing http://en.wikipedia.org/wiki/Logic_programming
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=3
# Indexing http://en.wikipedia.org/wiki/Strongly_typed_programming_language
# Indexing http://en.wikipedia.org/wiki/Undecidable_problem
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=18
# Indexing http://en.wikipedia.org/wiki/Special:Random
# Indexing http://en.wikipedia.org/wiki/File:Internet_map_1024.jpg
# Indexing http://en.wikipedia.org/wiki/Specification_language
# Indexing https://yo.wikipedia.org/wiki/%C3%88d%C3%A8_%C3%8C%E1%B9%A3%C3%A8l%C3%A0n%C3%A0_K%E1%BB%8D%CC%80mp%C3%BAt%C3%A0
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=19
# Indexing https://ms.wikipedia.org/wiki/Bahasa_pengaturcaraan
# Indexing http://en.wikipedia.org/wiki/Instruction_set
# Indexing http://www-pu.informatik.uni-tuebingen.de/users/klaeren/epigrams.html
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Verifiability
# Indexing http://en.wikipedia.org/wiki/Imperative_programming
# Indexing http://en.wikipedia.org/wiki/Semantics
# Indexing http://en.wikipedia.org/wiki/Logic
# Indexing https://wikimediafoundation.org/
# Indexing http://en.wikipedia.org/wiki/University_of_Manchester
# Indexing http://en.wikipedia.org/wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# Indexing https://commons.wikimedia.org/wiki/Category:Programming_languages
# Indexing http://en.wikipedia.org/wiki/Outline_of_computer_science
# Indexing http://en.wikipedia.org/wiki/Tony_Brooker
# Indexing https://zh-min-nan.wikipedia.org/wiki/Th%C3%AAng-sek_g%C3%AD-gi%C3%A2n
# Indexing http://en.wikipedia.org/wiki/Template_talk:Types_of_programming_languages
# Indexing https://en.wikinews.org/wiki/Special:Search/Programming_language
# Indexing http://en.wikipedia.org/wiki/Special:MyTalk
# Indexing http://id.loc.gov/authorities/subjects/sh85107313
# Indexing http://en.wikipedia.org/wiki/Natural_language_programming
# Indexing http://en.wikipedia.org/wiki/Special:WhatLinksHere/Programming_language
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Pending_changes
# Indexing http://en.wikipedia.org/wiki/Type_checking
# Indexing http://en.wikipedia.org/wiki/Magnetic_tape_data_storage
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Contact_us
# Indexing http://en.wikipedia.org/wiki/Communications_of_the_ACM
# Indexing http://en.wikipedia.org/wiki/Low-level_programming_language
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-534-94728-X
# Indexing http://en.wikipedia.org/wiki/Haskell_(programming_language)
# Could not open http://radar.oreilly.com/archives/2006/08/programming_language_trends_1.html
# Indexing http://en.wikipedia.org/wiki/Oracle_Corporation
# Indexing http://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Programming+language
# Indexing http://en.wikipedia.org/wiki/Formal_semantics_of_programming_languages
# Indexing http://en.wikipedia.org/wiki/Class-based_programming
# Indexing http://www.developer.com/lang/other/7-myths-of-cobol-debunked.html
# Indexing http://en.wikipedia.org/wiki/Website
# Indexing http://en.wikipedia.org/wiki/Theory_of_computation
# Indexing http://en.wikipedia.org/wiki/BCPL
# Could not open http://en.wikipedia.org/w/index.php?title=Muffy_Thomas&action=edit&redlink=1
# Indexing https://it.wikipedia.org/wiki/Linguaggio_di_programmazione
# Indexing http://en.wikipedia.org/wiki/Categorical_list_of_programming_languages
# Indexing http://en.wikipedia.org/wiki/C%2B%2B
# Could not open http://www.apl.jhu.edu/~hall/Lisp-Notes/Macros.html
# Indexing https://ky.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%BE%D0%BE_%D1%82%D0%B8%D0%BB%D0%B8
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=10
# Indexing http://en.wikipedia.org/wiki/Troff
# Indexing https://lmo.wikipedia.org/wiki/Lenguagg_de_programmazion
# Indexing http://en.wikipedia.org/wiki/Programming_language_specification
# Indexing http://en.wikipedia.org/wiki/Execution_(computing)
# Indexing https://be-x-old.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D1%8C%D0%BD%D1%8F
# Indexing http://en.wikipedia.org/wiki/High-level_programming_language
# Indexing http://en.wikipedia.org/wiki/Meta-circular_evaluator
# Indexing http://en.wikipedia.org/wiki/Polymorphism_in_object-oriented_programming
# Indexing http://en.wikipedia.org/wiki/Object-based_language
# Indexing http://en.wikipedia.org/wiki/Programming_language_implementation
# Indexing http://en.wikipedia.org/wiki/Konrad_Zuse
# Indexing http://en.wikipedia.org/wiki/Remington_Rand
# Indexing http://en.wikipedia.org/wiki/Shriram_Krishnamurthi
# Indexing http://en.wikipedia.org/wiki/Structured_data
# Indexing https://simple.wikipedia.org/wiki/Programming_language
# Indexing http://en.wikipedia.org/wiki/Luca_Cardelli
# Indexing http://en.wikipedia.org/wiki/Pipeline_programming
# Indexing http://home.mis.u-picardie.fr/~site-ic/site/IMG/pdf/ICSOFT2007_final.pdf
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-321-33025-0
# Indexing http://en.wikipedia.org/wiki/Machine_language
# Indexing http://en.wikipedia.org/wiki/Statement_(computer_science)
# Indexing https://eo.wikipedia.org/wiki/Programlingvo
# Indexing http://www.msnbc.msn.com/id/17704662/
# Indexing http://en.wikipedia.org/w/index.php?title=Programming_language&action=edit&section=8
# Could not open http://portal.acm.org/citation.cfm?id=155378
# Indexing http://en.wikipedia.org/wiki/Baghdad
# Indexing http://en.wikipedia.org/wiki/Delegation_(programming)
# Indexing http://en.wikipedia.org/wiki/Pascal_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Computer_language
# Indexing http://en.wikipedia.org/wiki/Perl
# Indexing https://yi.wikipedia.org/wiki/%D7%A4%D7%A8%D7%90%D7%92%D7%A8%D7%90%D7%9E%D7%99%D7%A8%D7%9F_%D7%A9%D7%A4%D7%A8%D7%90%D7%9A
# Indexing https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Indexing http://en.wikipedia.org/wiki/ML_(programming_language)
# Indexing http://en.wikipedia.org/wiki/Biblioth%C3%A8que_nationale_de_France
# Indexing http://en.wikipedia.org/wiki/Ferranti_Mercury
# Indexing http://wikimediafoundation.org/wiki/Terms_of_Use
# Indexing http://en.wikipedia.org/wiki/Debugging
# Indexing http://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_October_2008
# Indexing https://gl.wikipedia.org/wiki/Linguaxe_de_programaci%C3%B3n
# Indexing https://si.wikipedia.org/wiki/%E0%B6%9A%E0%B7%8A%E2%80%8D%E0%B6%BB%E0%B6%B8%E0%B6%BD%E0%B7%9A%E0%B6%9B%E0%B6%B1_%E0%B6%B7%E0%B7%8F%E0%B7%82%E0%B7%8F%E0%B7%80
# Indexing http://en.wikipedia.org/wiki/Knowledge_representation_language
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Citation_needed
# Indexing http://en.wikipedia.org/wiki/Disk_drive
# Indexing http://en.wikipedia.org/wiki/Digital_object_identifier
# Indexing http://en.wikipedia.org/wiki/Query_language
# Indexing https://en.wikipedia.org/w/index.php?title=Programming_language&oldid=802689990
# Indexing https://fr.wikipedia.org/wiki/Langage_de_programmation
# Indexing https://tg.wikipedia.org/wiki/%D0%97%D0%B0%D0%B1%D0%BE%D0%BD%D0%B8_%D0%B1%D0%B0%D1%80%D0%BD%D0%BE%D0%BC%D0%B0%D1%81%D0%BE%D0%B7%D3%A3
# Indexing http://en.wikipedia.org/wiki/Category:CS1_errors:_chapter_ignored
# Indexing http://en.wikipedia.org/wiki/International_Organization_for_Standardization
# Indexing http://en.wikipedia.org/wiki/Wikipedia:Community_portal
# Indexing https://en.wikiversity.org/wiki/Programming_languages
# Indexing http://en.wikipedia.org/wiki/John_C._Mitchell
# Indexing http://en.wikipedia.org/wiki/UCSD_Pascal
# Indexing http://en.wikipedia.org/wiki/ALGOL
# Could not open http://www.zib.de/zuse/Inhalt/Programme/Plankalkuel/Plankalkuel-Report/Plankalkuel-Report.htm
# Indexing http://en.wikipedia.org/wiki/SIGPLAN
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/1-86189-080-X
# Indexing http://en.wikipedia.org/wiki/SourceForge
# Indexing http://en.wikipedia.org/wiki/Standard_ML
# Indexing https://www.wikidata.org/wiki/Special:EntityPage/Q9143
# Indexing http://en.wikipedia.org/wiki/Domain_specific_language
# Indexing http://en.wikipedia.org/wiki/Data_structure
# Indexing https://pnb.wikipedia.org/wiki/%DA%A9%D9%85%D9%BE%DB%8C%D9%88%D9%B9%D8%B1_%D8%A8%D9%88%D9%84%DB%8C
# Indexing http://en.wikipedia.org/wiki/HTML
# Indexing http://en.wikipedia.org/wiki/%22Hello,_World!%22_program
# Indexing http://en.wikipedia.org/wiki/Special:BookSources/0-7645-8845-1
# Indexing http://en.wikipedia.org/wiki/Structured_English
# Indexing http://en.wikipedia.org/wiki/PHP
# Indexing https://ca.wikipedia.org/wiki/Llenguatge_de_programaci%C3%B3

# %%
#can check the entries for a word by querying the database
[row for row in crawler.con.execute('select rowid from word_location where word_id=1')]
#if using his data, should print 
#[(1,), (46,), (330,), (232,), (406,), (271,), (192,),...
# Out:
# [(1,),
#  (1050,),
#  (6003,),
#  (6016,),
#  (6611,),
#  (7119,),
#  (8506,),
#  (11188,),
#  (11982,),
#  (12087,),
#  (12122,),
#  (12347,),
#  (12541,),
#  (12544,),
#  (12556,),
#  (12933,),
#  (13551,),
#  (13575,),
#  (13658,),
#  (13708,),
#  (13718,),
#  (13730,),
#  (13832,),
#  (13996,),
#  (14371,),
#  (14566,),
#  (14942,),
#  (15258,),
#  (17074,),
#  (18642,),
#  (21432,),
#  (22417,),
#  (26125,),
#  (26129,),
#  (26142,),
#  (26143,),
#  (26162,),
#  (26167,),
#  (26171,),
#  (26200,),
#  (26300,),
#  (26351,),
#  (26470,),
#  (26530,),
#  (26541,),
#  (30570,),
#  (32245,),
#  (36240,),
#  (37826,),
#  (37850,),
#  (37871,),
#  (38325,),
#  (39030,),
#  (39523,),
#  (41245,),
#  (41273,),
#  (41322,),
#  (41352,),
#  (42442,),
#  (42550,),
#  (42578,),
#  (43229,),
#  (44439,),
#  (52527,),
#  (61834,),
#  (63616,),
#  (65568,),
#  (66112,),
#  (67249,),
#  (69736,),
#  (71425,),
#  (72424,),
#  (78454,),
#  (78913,),
#  (80761,),
#  (83373,),
#  (86355,),
#  (92628,),
#  (93260,),
#  (94233,),
#  (95872,),
#  (99938,),
#  (100586,),
#  (101893,),
#  (102242,),
#  (102877,),
#  (104832,),
#  (105625,),
#  (108898,),
#  (114928,),
#  (115387,),
#  (117096,),
#  (118442,),
#  (120115,),
#  (121048,),
#  (121642,),
#  (121657,),
#  (125816,),
#  (127737,),
#  (134885,),
#  (136371,),
#  (136987,),
#  (137285,),
#  (139091,),
#  (140790,),
#  (141270,),
#  (141384,),
#  (141413,),
#  (141475,),
#  (141640,),
